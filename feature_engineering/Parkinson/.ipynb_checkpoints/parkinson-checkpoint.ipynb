# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("parkinsons.data")
df.head(5)
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# 0      0.06545  0.02211  21.033       1  0.414783  0.815285 -4.813031
# 1      0.09403  0.01929  19.085       1  0.458359  0.819521 -4.075192
# 2      0.08270  0.01309  20.651       1  0.429895  0.825288 -4.443179
# 3      0.08771  0.01353  20.644       1  0.434969  0.819235 -4.117501
# 4      0.10470  0.01767  19.649       1  0.417356  0.823484 -3.747787
#
#     spread2        D2       PPE
# 0  0.266482  2.301442  0.284654
# 1  0.335590  2.486855  0.368674
# 2  0.311173  2.342259  0.332634
# 3  0.334147  2.405554  0.368975
# 4  0.234513  2.332180  0.410335
#
# [5 rows x 24 columns]

# %%
df.shape
# Out:
# (195, 24)

# %%
df.dtypes
# Out:
# subject#           int64
# age                int64
# sex                int64
# test_time        float64
# motor_UPDRS      float64
# total_UPDRS      float64
# Jitter(%)        float64
# Jitter(Abs)      float64
# Jitter:RAP       float64
# Jitter:PPQ5      float64
# Jitter:DDP       float64
# Shimmer          float64
# Shimmer(dB)      float64
# Shimmer:APQ3     float64
# Shimmer:APQ5     float64
# Shimmer:APQ11    float64
# Shimmer:DDA      float64
# NHR              float64
# HNR              float64
# RPDE             float64
# DFA              float64
# PPE              float64
# dtype: object

# %%
df = df.drop(['subject#','test_time'], axis = 1)

# %%
df
# Out:
#       age  sex  motor_UPDRS  total_UPDRS  Jitter(%)  Jitter(Abs)  Jitter:RAP  \
# 0      72    0       28.199       34.398    0.00662     0.000034     0.00401
# 1      72    0       28.447       34.894    0.00300     0.000017     0.00132
# 2      72    0       28.695       35.389    0.00481     0.000025     0.00205
# 3      72    0       28.905       35.810    0.00528     0.000027     0.00191
# 4      72    0       29.187       36.375    0.00335     0.000020     0.00093
# ...   ...  ...          ...          ...        ...          ...         ...
# 5870   61    0       22.485       33.485    0.00406     0.000031     0.00167
# 5871   61    0       21.988       32.988    0.00297     0.000025     0.00119
# 5872   61    0       21.495       32.495    0.00349     0.000025     0.00152
# 5873   61    0       21.007       32.007    0.00281     0.000020     0.00128
# 5874   61    0       20.513       31.513    0.00282     0.000021     0.00135
#
#       Jitter:PPQ5  Jitter:DDP  Shimmer  Shimmer(dB)  Shimmer:APQ3  \
# 0         0.00317     0.01204  0.02565        0.230       0.01438
# 1         0.00150     0.00395  0.02024        0.179       0.00994
# 2         0.00208     0.00616  0.01675        0.181       0.00734
# 3         0.00264     0.00573  0.02309        0.327       0.01106
# 4         0.00130     0.00278  0.01703        0.176       0.00679
# ...           ...         ...      ...          ...           ...
# 5870      0.00168     0.00500  0.01896        0.160       0.00973
# 5871      0.00147     0.00358  0.02315        0.215       0.01052
# 5872      0.00187     0.00456  0.02499        0.244       0.01371
# 5873      0.00151     0.00383  0.01484        0.131       0.00693
# 5874      0.00166     0.00406  0.01907        0.171       0.00946
#
#       Shimmer:APQ5  Shimmer:APQ11  Shimmer:DDA       NHR     HNR     RPDE  \
# 0          0.01309        0.01662      0.04314  0.014290  21.640  0.41888
# 1          0.01072        0.01689      0.02982  0.011112  27.183  0.43493
# 2          0.00844        0.01458      0.02202  0.020220  23.047  0.46222
# 3          0.01265        0.01963      0.03317  0.027837  24.445  0.48730
# 4          0.00929        0.01819      0.02036  0.011625  26.126  0.47188
# ...            ...            ...          ...       ...     ...      ...
# 5870       0.01133        0.01549      0.02920  0.025137  22.369  0.64215
# 5871       0.01277        0.01904      0.03157  0.011927  22.886  0.52598
# 5872       0.01456        0.01877      0.04112  0.017701  25.065  0.47792
# 5873       0.00870        0.01307      0.02078  0.007984  24.422  0.56865
# 5874       0.01154        0.01470      0.02839  0.008172  23.259  0.58608
#
#           DFA      PPE
# 0     0.54842  0.16006
# 1     0.56477  0.10810
# 2     0.54405  0.21014
# 3     0.57794  0.33277
# 4     0.56122  0.19361
# ...       ...      ...
# 5870  0.55314  0.21367
# 5871  0.56518  0.12621
# 5872  0.57888  0.14157
# 5873  0.56327  0.14204
# 5874  0.57077  0.15336
#
# [5875 rows x 20 columns]

# %% [markdown]
# # feature engineering

# %%
# Deal with age: scale age to [1,6]
for idx in df["age"].index:

    if (df['age'][idx] >= 70 and df['age'][idx] < 80) :
        df['age'][idx] = 5
    elif(df['age'][idx] >= 80 and df['age'][idx] < 90):
        df['age'][idx] = 6
    elif(df['age'][idx] >= 60 and df['age'][idx] < 70):
        df['age'][idx] = 4
    elif(df['age'][idx] >= 50 and df['age'][idx] < 60):
        df['age'][idx] = 3
    elif(df['age'][idx] >= 40 and df['age'][idx] < 50):
        df['age'][idx] = 2
    elif(df['age'][idx] >= 30 and df['age'][idx] < 40):
        df['age'][idx] = 1
    else:
        df['age'][idx] = 0
# Out:
# <ipython-input-118-4541fb15a1ed>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['age'][idx] = 5
# <ipython-input-118-4541fb15a1ed>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['age'][idx] = 3
# <ipython-input-118-4541fb15a1ed>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['age'][idx] = 4
# <ipython-input-118-4541fb15a1ed>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['age'][idx] = 2
# <ipython-input-118-4541fb15a1ed>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['age'][idx] = 1
# <ipython-input-118-4541fb15a1ed>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['age'][idx] = 6

# %%
df["age"].value_counts()
# Out:
# 4    2127
# 5    1729
# 3    1520
# 2     256
# 6     142
# 1     101
# Name: age, dtype: int64

# %%
df["age"]
# Out:
# 0       5
# 1       5
# 2       5
# 3       5
# 4       5
#        ..
# 5870    4
# 5871    4
# 5872    4
# 5873    4
# 5874    4
# Name: age, Length: 5875, dtype: int64

# %%
# Deal with total_updrs: scale score to
for idx in df["total_UPDRS"].index:

    if (df['age'][idx] >= 70 and df['age'][idx] < 80) :
        df['age'][idx] = 5
    elif(df['age'][idx] >= 80 and df['age'][idx] < 90):
        df['age'][idx] = 6
    elif(df['age'][idx] >= 60 and df['age'][idx] < 70):
        df['age'][idx] = 4
    elif(df['age'][idx] >= 50 and df['age'][idx] < 60):
        df['age'][idx] = 3
    elif(df['age'][idx] >= 40 and df['age'][idx] < 50):
        df['age'][idx] = 2
    elif(df['age'][idx] >= 30 and df['age'][idx] < 40):
        df['age'][idx] = 1
    else:
        df['age'][idx] = 0

# %%
fig,axes=plt.subplots(5,5,figsize=(15,15))
axes=axes.flatten()

for i in range(1,len(df.columns)-1):
    sns.boxplot(x='total_UPDRS',y=data_master.iloc[:,i],data=df,orient='v',ax=axes[i])
plt.tight_layout()
plt.show()

# %%
df.status.value_counts()
# Out:
# 1    147
# 0     48
# Name: status, dtype: int64

# %%
df['MDVP:RAP']
# Out:
# 0      0.00370
# 1      0.00465
# 2      0.00544
# 3      0.00502
# 4      0.00655
#         ...
# 190    0.00263
# 191    0.00331
# 192    0.00624
# 193    0.00370
# 194    0.00295
# Name: MDVP:RAP, Length: 195, dtype: float64
